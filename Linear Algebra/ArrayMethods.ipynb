# %%
import numpy as np

# %%
a = np.random.randint(10,50, size=(5,2,3), dtype="int8")

# %%
a.shape
# Out:
# (5, 2, 3)

# %%
a.ndim
# Out:
# 3

# %%
a.dtype
# Out:
# dtype('int8')

# %%
a.size
# Out:
# 30

# %%
a.T
# Out:
# array([[[45, 20, 41, 11, 48],
#         [38, 33, 36, 15, 21]],
#
#        [[41, 47, 36, 43, 48],
#         [17, 35, 15, 27, 46]],
#
#        [[29, 44, 29, 29, 22],
#         [33, 22, 23, 14, 30]]], dtype=int8)

# %%
a.shape
# Out:
# (5, 2, 3)

# %%
a.reshape(3,5,2)
# Out:
# array([[[45, 41],
#         [29, 38],
#         [17, 33],
#         [20, 47],
#         [44, 33]],
#
#        [[35, 22],
#         [41, 36],
#         [29, 36],
#         [15, 23],
#         [11, 43]],
#
#        [[29, 15],
#         [27, 14],
#         [48, 48],
#         [22, 21],
#         [46, 30]]], dtype=int8)

# %%
a.reshape(3,-1,1)
# Out:
# array([[[45],
#         [41],
#         [29],
#         [38],
#         [17],
#         [33],
#         [20],
#         [47],
#         [44],
#         [33]],
#
#        [[35],
#         [22],
#         [41],
#         [36],
#         [29],
#         [36],
#         [15],
#         [23],
#         [11],
#         [43]],
#
#        [[29],
#         [15],
#         [27],
#         [14],
#         [48],
#         [48],
#         [22],
#         [21],
#         [46],
#         [30]]], dtype=int8)

# %%
a.ravel()
# Out:
# array([45, 41, 29, 38, 17, 33, 20, 47, 44, 33, 35, 22, 41, 36, 29, 36, 15,
#        23, 11, 43, 29, 15, 27, 14, 48, 48, 22, 21, 46, 30], dtype=int8)

# %%
b = np.random.randint(1,10,(2,3))
c = np.random.randint(1,10,(2,3))
b,c
# Out:
# (array([[8, 8, 5],
#         [2, 3, 6]], dtype=int32),
#  array([[2, 3, 3],
#         [2, 3, 7]], dtype=int32))

# %%
d = np.concatenate([b,c],axis=0)
d
# Out:
# array([[8, 8, 5],
#        [2, 3, 6],
#        [2, 3, 3],
#        [2, 3, 7]], dtype=int32)

# %%
np.vstack((b,c))
# Out:
# array([[8, 8, 5],
#        [2, 3, 6],
#        [2, 3, 3],
#        [2, 3, 7]], dtype=int32)

# %%
np.hstack((b,c))
# Out:
# array([[8, 8, 5, 2, 3, 3],
#        [2, 3, 6, 2, 3, 7]], dtype=int32)

# %%
np.split(d,3,axis=1)
# Out:
# [array([[8],
#         [2],
#         [2],
#         [2]], dtype=int32),
#  array([[8],
#         [3],
#         [3],
#         [3]], dtype=int32),
#  array([[5],
#         [6],
#         [3],
#         [7]], dtype=int32)]
