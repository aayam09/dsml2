# %% [markdown]
# ## Python Text Type

# %% [markdown]
# ## Defining Strings

# %%
name = "aayam"

# %%
type(name)
# Out:
# str

# %%
text = """one
two
three
"""

# %%
print(text)
# Out:
# one
# two
# three

# %%
str(22)
# Out:
# '22'

# %%
len(name)
# Out:
# 5

# %% [markdown]
# ## String methods

# %%
x = " welcome "

# %%
x.lower()
# Out:
# ' welcome '

# %%
x.upper()
# Out:
# ' WELCOME '

# %%
x.strip()
# Out:
# 'welcome'

# %%
x.replace('e','a')
# Out:
# ' walcoma '

# %%
x.split('e')
# Out:
# [' w', 'lcom', ' ']

# %%
email = "test@gmail.com"

# %%
email.endswith("gmail.com")
# Out:
# True

# %% [markdown]
# ## String indexing

# %%
address = "kathmandu"

# %%
address[5]
# Out:
# 'a'

# %%
address[-1]
# Out:
# 'u'
