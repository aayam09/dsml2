# %%
import pandas as pd

titanic_df = pd.read_csv("titanic-data.csv")

# %% [markdown]
# ## Basic Information

# %%
titatic_df.shape
# Out:
# (891, 12)

# %%
titatic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
titatic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
titatic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titatic_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ## Specific Infromation

# %%
titatic_df[["Age","Fare"]].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
titatic_df[["Age","Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %% [markdown]
# ### Descriptive Statistics of Age and Fare
#
# The summary statistics provide an overview of the **Age** and **Fare** variables in the Titanic dataset.
#
# | Statistic | Age | Fare |
# |----------|---------:|---------:|
# | Count | 714 | 891 |
# | Mean | 29.70 | 32.20 |
# | Standard Deviation | 14.53 | 49.69 |
# | Minimum | 0.42 | 0.00 |
# | 25th Percentile | 20.13 | 7.91 |
# | Median (50%) | 28.00 | 14.45 |
# | 75th Percentile | 38.00 | 31.00 |
# | Maximum | 80.00 | 512.33 |
#
# **Observation:**
#
# - The **Age** column contains **714** non-null values, indicating that some passenger ages are missing, whereas the **Fare** column has no missing values.
# - The average passenger age is **29.7 years**, with most passengers being between **20 and 38 years** old.
# - Passenger fares vary considerably, with an average fare of **32.20** and values ranging from **0.00** to **512.33**.
# - The high standard deviation of the **Fare** column suggests a wide variation in ticket prices, likely due to differences in passenger class and ticket type.

# %%
titatic_df.value_counts("Survived")
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titatic_df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titatic_df.value_counts(["Sex","Survived"],normalize=True)
# Out:
# Sex     Survived
# male    0           0.525253
# female  1           0.261504
# male    1           0.122334
# female  0           0.090909
# Name: proportion, dtype: float64

# %% [markdown]
# ### Distribution of Passengers by Sex and Survival Status
#
# This analysis presents the proportion of passengers based on their gender and survival status.
#
# | Sex | Survived | Proportion |
# |------|----------|-----------:|
# | Male | No (0) | 52.53% |
# | Female | Yes (1) | 26.15% |
# | Male | Yes (1) | 12.23% |
# | Female | No (0) | 9.09% |
#
# **Observation:**
#
# - The largest group in the dataset consists of **male passengers who did not survive (52.53%)**.
# - **Female survivors account for 26.15%** of the total passengers, which is higher than the proportion of male survivors (12.23%).
# - Overall, female passengers exhibited a higher survival rate than male passengers, indicating that gender was a significant factor influencing survival.

# %%
titanic_df.value_counts(["Sex", "Survived"], normalize=True, ascending=True)
# Out:
# Sex     Survived
# female  0           0.090909
# male    1           0.122334
# female  1           0.261504
# male    0           0.525253
# Name: proportion, dtype: float64

# %%
titanic_df[titanic_df["Sex"]=="female"].value_counts("Survived",normalize=True,ascending=True)
# Out:
# Survived
# 0    0.257962
# 1    0.742038
# Name: proportion, dtype: float64

# %% [markdown]
# ### Female Survival Distribution
#
# The analysis shows the distribution of survival outcomes among female passengers. Approximately **74.20%** of female passengers survived, while **25.80%** did not survive. This indicates that the majority of female passengers survived the Titanic disaster, suggesting that gender was an important factor influencing survival.

# %%
titanic_df.value_counts("Embarked")
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titatic_df[titanic_df.Embarked == "S"].value_counts("Sex")
# Out:
# Sex
# male      441
# female    203
# Name: count, dtype: int64

# %% [markdown]
# ### Distribution of Passengers Embarked from Southampton (S) by Gender
#
# The following analysis shows the number of male and female passengers who boarded the Titanic from **Southampton (S)**.
#
# | Sex | Count |
# |------|------:|
# | Male | 441 |
# | Female | 203 |
#
# **Observation:**
#
# - A total of **644 passengers** embarked from **Southampton (S)**.
# - Among them, **441 (68.48%)** were male and **203 (31.52%)** were female.
# - Male passengers constituted the majority of passengers embarking from Southampton.

# %%
titatic_df[titanic_df.Embarked == "S"].value_counts("Survived")
# Out:
# Survived
# 0    427
# 1    217
# Name: count, dtype: int64

# %% [markdown]
# ### Survival Distribution of Passengers Embarked from Southampton (S)
#
# The following analysis shows the survival status of passengers who embarked from **Southampton (S)**.
#
# | Survived | Count |
# |----------|------:|
# | No (0) | 427 |
# | Yes (1) | 217 |
#
# **Observation:**
#
# - A total of **644 passengers** boarded the Titanic from **Southampton (S)**.
# - Among them, **427 (66.30%)** did not survive, while **217 (33.70%)** survived.
# - The majority of passengers embarking from Southampton did not survive the disaster.

# %%
# nunique(), unique()
titanic_df["Embarked"].unique()
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
titanic_df["Embarked"].nunique()
# Out:
# 3

# %%
titanic_df.isna().sum() #find total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
group_by_gender = titanic_df[["Sex","Fare","Age","Survived"]].groupby(by = "Sex")

# %%
group_by_gender.mean()
# Out:
#              Fare        Age  Survived
# Sex
# female  44.479818  27.915709  0.742038
# male    25.523893  30.726645  0.188908

# %%
group_by_gender.value_counts(["Survived"])
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
group_by_embarked = titanic_df[["Embarked","Fare","Age","Survived"]].groupby(by = ["Embarked","Survived"])

# %%
group_by_embarked.min()
# Out:
#                      Fare    Age
# Embarked Survived
# C        0         4.0125   9.00
#          1         7.2250   0.42
# Q        0         6.7500   2.00
#          1         7.7333  15.00
# S        0         0.0000   1.00
#          1         0.0000   0.67

# %% [markdown]
# ## Correlation and covariance

# %%
titanic_df[["Age","Fare"]].cov()
# Out:
#              Age         Fare
# Age   211.019125    73.849030
# Fare   73.849030  2469.436846

# %%
titanic_df[["Age","Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000

# %%
sampled = titanic_df.sample(n= 100, random_state=99)

# %%
sampled[["Age","Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.120865
# Fare  0.120865  1.000000

# %%
pd.crosstab(titanic_df.Sex,
            titanic_df.Survived,
            margins=True,
)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
pd.crosstab([titanic_df.Embarked,titanic_df.Pclass],[titanic_df.Sex,titanic_df.Survived],margins=True)
# Out:
# Sex             female      male       All
# Survived             0    1    0    1
# Embarked Pclass
# C        1           1   42   25   17   85
#          2           0    7    8    2   17
#          3           8   15   33   10   66
# Q        1           0    1    1    0    2
#          2           0    2    1    0    3
#          3           9   24   36    3   72
# S        1           2   46   51   28  127
#          2           6   61   82   15  164
#          3          55   33  231   34  353
# All                 81  231  468  109  889
