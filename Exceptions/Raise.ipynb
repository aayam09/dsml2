# %%
number = "45"

if isinstance(number,int):
    print(f"Square of {number} is {number ** 2}")
else:
    raise TypeError("value should be integer")
# Out:
# -------------------------------------
# TypeErrorTraceback (most recent call last)
# Cell In[3], line 6
#       2
#       3 if isinstance(number,int):
#       4     print(f"Square of {number} is {number ** 2}")
#       5 else:
# ----> 6     raise TypeError("value should be integer")
#
# TypeError: value should be integer

# %% [markdown]
# ## Python raise Statement

# %%
x = 2
y =0 

if y == 0:
    raise ValueError("divoiser should not be zero")
# Out:
# -------------------------------------
# ValueErrorTraceback (most recent call last)
# Cell In[5], line 5
#       1 x = 2
#       2 y =0
#       3
#       4 if y == 0:
# ----> 5     raise ValueError("divoiser should not be zero")
#
# ValueError: divoiser should not be zero

# %% [markdown]
# ### User-defined Esception

# %%
class UserNotFound(Exception):
    pass

# %%
def get_user(user_id):
    """


    """
    raise UserNotFound(f"no user with this is {user_id}")

# %%
get_user("ram")
# Out:
# -------------------------------------
# UserNotFoundTraceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_user("ram")
#
# Cell In[7], line 6, in get_user(user_id)
#       2     """
#       3
#       4
#       5     """
# ----> 6     raise UserNotFound(f"no user with this is {user_id}")
#
# UserNotFound: no user with this is ram
