# %% [markdown]
# ## Puthon built-in Function

# %% [markdown]
# ### print()

# %%
print(4,5, sep=",")
# Out:
# 4,5

# %%
print("Hello", "World", sep=",", end =".")
# Out:
# Hello,World.

# %%
print("Hello", "World", sep=",", end ="\n")
print("Welcome", end=".")
# Out:
# Hello,World
# Welcome.

# %% [markdown]
# ### Input()

# %%
name = input("enter your name")
# Out:
# enter your name aayam

# %%
name
# Out:
# 'aayam'

# %%
age = int(input("enter your age"))
# Out:
# enter your age 3

# %%
age
# Out:
# 3

# %% [markdown]
# ### type()

# %%
type(3.8)
# Out:
# float

# %%
type({})
# Out:
# dict

# %%
type(4 == 2)
# Out:
# bool

# %%
type(sum)
# Out:
# builtin_function_or_method

# %% [markdown]
# ### len()

# %%
len("apple")
# Out:
# 5

# %%
len(["Harri","salmon","ad","john"])
# Out:
# 4

# %%
len({1:"apple",2:"banana"})
# Out:
# 2

# %%
divmod(5,2)
# Out:
# (2, 1)
