# %% [markdown]
# ## Python OS module

# %% [markdown]
# ### working with files and Directories

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\dsml\\dsml2\\ModulesandPackages'

# %%
if not os.path.exists("testfolder/"):
    os.mkdir("testfolder")
else:
    print("path exits")
# Out:
# path exits

# %%
os.chdir("D:\\dsml\\dsml2\\ModulesandPackages\\")

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'DateTime.ipynb',
#  'Mathmodule.ipynb',
#  'OSmodule.ipynb',
#  'testfolder']

# %%
os.rmdir("testfolder/")
# Out:
# -------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.rmdir("testfolder/")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'testfolder/'

# %%
# os.remove()

# %% [markdown]
# ### Working with Environment Variables

# %%
os.getenv("Home")
# Out:
# 'C:\\Users\\Acer'

# %%
os.getenv("oneDrive")
# Out:
# 'C:\\Users\\Acer\\OneDrive'

# %%
os.environ["Mypassword"] = "secret_password"

# %%
os.getenv("Mypassword")
# Out:
# 'secret_password'
