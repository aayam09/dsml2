# %% [markdown]
# ## Python Math Module

# %%
import math

# %%
math.pow(4,3)
# Out:
# 64.0

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.ceil(2.333301)
# Out:
# 3

# %%
math.floor(2.98999)
# Out:
# 2

# %% [markdown]
# ### Trignometric functon

# %%
d_to_r = math.radians(30)
d_to_r
# Out:
# 0.5235987755982988

# %%
math.sin(d_to_r)
# Out:
# 0.49999999999999994

# %%
math.hypot(3,4)
# Out:
# 5.0

# %% [markdown]
# ### Expontial and Logarithm Function

# %%
math.exp(0)
# Out:
# 1.0

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
math.log(100)
# Out:
# 4.605170185988092

# %% [markdown]
# ### Constants

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %% [markdown]
# ### Special Functions

# %%
math.factorial(10)
# Out:
# 3628800

# %%
math.comb(5,4)
# Out:
# 5

# %%
math.perm(5,4)
# Out:
# 120
