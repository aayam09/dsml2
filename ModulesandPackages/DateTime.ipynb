# %% [markdown]
# ## Modules and Packages

# %% [markdown]
# ### Python Date and Time Modules

# %% [markdown]
# #### 1. datetime

# %%
import datetime

# %%
# '2025/07/14'
date1 = datetime.date(2026, 8, 14)

# %%
date1
# Out:
# datetime.date(2026, 8, 14)

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2026-06-09

# %%
# compare Date
date1  > today
# Out:
# True

# %%
# arith. operation

date1 - today
# Out:
# datetime.timedelta(days=66)

# %%
get_time = datetime.time(12,54,6)

# %%
get_time
# Out:
# datetime.time(12, 54, 6)

# %%
now = datetime.datetime.today()
now
# Out:
# datetime.datetime(2026, 6, 9, 14, 3, 9, 669195)

# %%
now.strftime("%Y/%m/%d %H:%M:%S")
# Out:
# '2026/06/09 14:03:09'

# %%
year10 = datetime.timedelta(days = 10*365)
datetime.datetime(1998,5,25) + year10
# Out:
# datetime.datetime(2008, 5, 22, 0, 0)

# %%
nst = datetime.timezone(datetime.timedelta(hours = 5, minutes =45))

# %%
print(nst)
# Out:
# UTC+05:45

# %% [markdown]
# ### 2. Time

# %%
import time

# %%
time.time()
# Out:
# 1781015560.7383115

# %%
time.ctime()
# Out:
# 'Tue Jun  9 20:18:16 2026'

# %%
#sleep for 2 sec
print("loading ...")
time.sleep(5)
print("Completed")
# Out:
# loading ...
# Completed

# %%
# Current UTC time
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=6, tm_mday=9, tm_hour=14, tm_min=36, tm_sec=2, tm_wday=1, tm_yday=160, tm_isdst=0)

# %%
#str Repr
time.strftime("%H hour: %M minutes: %S secoends")
# Out:
# '20 hour: 27 minutes: 11 secoends'

# %%
start = time.time()

print("hello")
time.sleep(2)

end = time.time()
# Out:
# hello

# %%
print("total time taken",end -start)
# Out:
# total time taken 2.0015881061553955

# %%
end =time.time()

# %%
end / 3600
# Out:
# 494726.7591380218
