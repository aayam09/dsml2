# %% [markdown]
# ## Python random Module

# %% [markdown]
# ### Uniform Distrubution function

# %%
import random

# %%
random.random()
# Out:
# 0.8589611097144257

# %%
random.uniform(100,500)
# Out:
# 405.1676915657169

# %%
random.randint(100,550)
# Out:
# 526

# %%
random.randrange(100,501,50)
# Out:
# 100

# %% [markdown]
# ### Sequence related functions

# %%
cards = ['ace', 'king', 'queen', 'jack', 'ten' , 'nine']

# %%
random.choice(cards)
# Out:
# 'jack'

# %%
random.shuffle(cards)

# %%
cards
# Out:
# ['king', 'ace', 'queen', 'ten', 'nine', 'jack']

# %%
random.sample(cards, 3)
# Out:
# ['king', 'queen', 'jack']

# %%
random.choices(cards, weights=[0.2,0.12,0.1,0.4,0.25,0.33], k= 2)
# Out:
# ['king', 'ten']

# %% [markdown]
# ### Distributions and probalilty density function

# %%
random.triangular(0,10,5)
# Out:
# 6.603214037229553

# %% [markdown]
# ### Randomness-related function

# %%
random.seed(555)

# %%
random.randint(1,10)
# Out:
# 9

# %%
import random

state = random.getstate()

a = random.randint(1,10)
b = random.randint(1,10)
c = random.randint(1,10)

print(a,b,c)
# Out:
# 6 3 4

# %%
import random

state = random.setstate(state)

a = random.randint(1,10)
b = random.randint(1,10)
c = random.randint(1,10)

print(a,b,c)
# Out:
# 6 3 4
