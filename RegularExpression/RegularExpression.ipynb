# %% [markdown]
# ## Regular expression in Python

# %%
import re

# %%
string = "The quick brown fox jumps over the lazy dog"
pattern = r"he"

match = re.search(pattern,string)

# %%
match.group()
# Out:
# 'he'

# %% [markdown]
# ### 1. re.Search

# %%
# Using re.search() with conditional expressions

if match:
    print("Match Object:", match)
    print("Match Group:", match.group())
    print("Match Start:", match.start())
    print("Match End:", match.end())
    print("Match Span:", match.span())
else:
    print("No match found.")
# Out:
# Match Object: <re.Match object; span=(1, 3), match='he'>
# Match Group: he
# Match Start: 1
# Match End: 3
# Match Span: (1, 3)

# %% [markdown]
# ### 2.re.findall

# %%
string = "The quick brown fox jumps over the lazy dog"
pattern = r"[A-z]he"

match = re.findall(pattern,string)

# %%
match
# Out:
# ['The', 'the']

# %% [markdown]
# ### 3. re.sub

# %%
string = "The quick brown fox jumps over the lazy dog"
pattern = r"[A-z]he"
repl = "the"

match = re.sub(pattern, repl, string, count=1)

# %%
match
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %% [markdown]
# ### 4. re.split

# %%
string = "The quick brown fox jumps over the 40 m lazy dog"
pattern = r"[0-9]+"

segments = re.split(pattern, string, maxsplit=0)

# %%
segments
# Out:
# ['The quick brown fox jumps over the ', ' m lazy dog']

# %%
res = re.sub(r"[^\w\s]", "", "amazonaws.com/clip_test_videos/smin_test.mp4")

# %%
res
# Out:
# 'amazonawscomclip_test_videossmin_testmp4'
