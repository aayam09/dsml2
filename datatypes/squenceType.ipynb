# %% [markdown]
# ## Python Sequence types

# %% [markdown]
# ## 1. List

# %% [markdown]
# ## Defining List

# %%
prime = [1,3,5,7,11,13,1,7,23,29]

# %%
type(prime)
# Out:
# list

# %%
z = ["apple", 11,34 ,"34gh", -9, True]

# %%
print(z)
# Out:
# ['apple', 11, 34, '34gh', -9, True]

# %%
len(z)
# Out:
# 6

# %% [markdown]
# ## Accessing List item

# %%
z[-3]
# Out:
# '34gh'

# %%
z[2]
# Out:
# 34

# %% [markdown]
# ## Slicing list

# %%
prime = [1,3,5,7,11,13,17,23,29]

# %%
prime[2::2]
# Out:
# [5, 11, 17, 29]

# %%
prime[::-1]
# Out:
# [29, 23, 17, 13, 11, 7, 5, 3, 1]

# %% [markdown]
# ## Modifying List

# %%
z = ["apple", 11.34 ,"34gh", -9, True]

# %%
z[2] = "John"

# %%
print(z)
# Out:
# ['apple', 11.34, 'John', -9, True]

# %%
z.append(66)

# %%
print(z)
# Out:
# ['apple', 11.34, 'John', -9, True, 66]

# %%
z.insert(1, "cow")

# %%
print(z)
# Out:
# ['apple', 'cow', 11.34, 'John', -9, True, 66]

# %%
z.extend([1,2,3])

# %%
print(z)
# Out:
# ['apple', 'cow', 11.34, 'John', -9, True, 66, 1, 2, 3]

# %%
z.remove(-9)

# %%
print(z)
# Out:
# ['apple', 'cow', 11.34, 'John', True, 66, 1, 2, 3]

# %%
z.pop()
# Out:
# 3

# %%
print(z)
# Out:
# ['apple', 'cow', 11.34, 'John', True, 66, 1, 2]

# %%
z.clear()

# %%
print(z)
# Out:
# []

# %%
name = ["hari", "shyam", "ram"]

# %%
name_new = name.copy()

# %%
name_new
# Out:
# ['hari', 'shyam', 'ram']

# %%
name_new.append("Krishna")

# %%
name_new
# Out:
# ['hari', 'shyam', 'ram', 'Krishna']

# %%
name
# Out:
# ['hari', 'shyam', 'ram']

# %% [markdown]
# ## List Methods

# %%
mylist = [3,1,99,1,5,1]

# %%
print(mylist)
# Out:
# [3, 1, 99, 1, 5, 1]

# %%
mylist.sort(reverse=True)

# %%
print(mylist)
# Out:
# [99, 5, 3, 1, 1, 1]

# %%
mylist.reverse()

# %%
print(mylist)
# Out:
# [1, 1, 1, 3, 5, 99]

# %%
mylist.count(1)
# Out:
# 3

# %%
mylist.index(1)
# Out:
# 0

# %% [markdown]
# ## 2. Tuple

# %% [markdown]
# ## Creating as tuple

# %%
mytuple = (720, 108, 23)

# %%
print(mytuple)
# Out:
# (720, 108, 23)

# %%
type(mytuple)
# Out:
# tuple

# %% [markdown]
# ### Accessing tuple elements

# %%
mytuple[0]
# Out:
# 720

# %%
mytuple[-1]
# Out:
# 23

# %% [markdown]
# ### Slicing Touple

# %%
longtouple = (1,3,45,67,46,8)

# %%
print(longtouple)
# Out:
# (1, 3, 45, 67, 46, 8)

# %%
longtouple[2:6]
# Out:
# (45, 67, 46, 8)

# %% [markdown]
# ### Modifying tuoples

# %%
longtouple[0] =5
# Out:
# ----------------------------------------------------
# TypeError          Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 longtouple[0] =5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Tuple Methods

# %%
longtouple.count(3)
# Out:
# 1

# %%
sorted(longtouple)
# Out:
# [1, 3, 8, 45, 46, 67]

# %% [markdown]
# ### Type Conversion

# %%
list(longtouple)
# Out:
# [1, 3, 45, 67, 46, 8]

# %%
tuple(mylist)
# Out:
# (1, 1, 1, 3, 5, 99)
