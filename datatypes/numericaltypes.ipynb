# %% [markdown]
#  # Int

# %%
number = 1234567

# %%
type(number)
# Out:
# int

# %%
print(number)
# Out:
# 1234567

# %% [markdown]
# ## float

# %%
pie = 22/7

# %%
print(pie)
# Out:
# 3.142857142857143

# %%
type(pie)
# Out:
# float

# %% [markdown]
# ## complex

# %%
vec = 6-3j

# %%
type(vec)
# Out:
# complex

# %% [markdown]
# ## Arithmetic Operation

# %%
x = 22
y = 55.6

# %%
x + y
# Out:
# 77.6

# %%
x - y
# Out:
# -33.6

# %%
x * y
# Out:
# 1223.2

# %%
x / y
# Out:
# 0.39568345323741005

# %%
10 % 3
# Out:
# 1

# %%
10 ** 3
# Out:
# 1000

# %%
100 // 6
# Out:
# 16

# %% [markdown]
# ## Type coversion

# %%
eulers = 6.577218

# %%
number = int(eulers)

# %%
number
# Out:
# 6

# %%
whole = 90

# %%
float(whole)
# Out:
# 90.0

# %%
complex(34,66.7)
# Out:
# (34+66.7j)

# %% [markdown]
# Comparision Operater

# %%
num1 = 77
num2 = 89.3

# %%
num1 == num2
# Out:
# False

# %%
num1 >= num2
# Out:
# False

# %% [markdown]
# ## Math function

# %%
import math

# %%
x = -22.5

# %%
math.fabs(x)
# Out:
# 22.5

# %%
math.gcd(3,6,9,12)
# Out:
# 3

# %%
math.ceil(44.2)
# Out:
# 45

# %%
math.floor(44.6)
# Out:
# 44

# %%
math.isfinite(22/7)
# Out:
# True

# %%
math.dist((3,4),(5,7))
# Out:
# 3.605551275463989

# %%
user = 6700
capacity = 120

# %%
result = min(user, capacity)

# %%
result
# Out:
# 120
