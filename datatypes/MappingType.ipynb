# %% [markdown]
# ## Mapping Type

# %% [markdown]
# ### Creating a dictionary

# %% [markdown]
# ```
# dist = {
#     key : value,
#     key2 : value2,
# }
# ```

# %%
person = {
    "name" : "aayam",
    "age" :20,
    "Gender" : "Male",
    "subjects" :  ["maths", "Science"]
}

# %%
type(person)
# Out:
# dict

# %%
person = dict(name = "john", city = "NYC")

# %% [markdown]
# ### Accessing Elements

# %%
person["age"]
# Out:
# 20

# %%
person["Dob"]
# Out:
# ----------------------------------------------------
# KeyError           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 person["Dob"]
#
# KeyError: 'Dob'

# %%
person.get("Dob",1990)
# Out:
# 1990

# %%
person.get("subjects")
# Out:
# ['maths', 'Science']

# %% [markdown]
# ### Modifying Elements

# %%
print(person)
# Out:
# {'name': 'aayam', 'age': 20, 'Gender': 'Male', 'subjects': ['maths', 'Science']}

# %%
person["age"] = 60

# %%
print(person)
# Out:
# {'name': 'aayam', 'age': 60, 'Gender': 'Male', 'subjects': ['maths', 'Science']}

# %%
person["city"] = "baltimore"

# %%
print(person)
# Out:
# {'name': 'aayam', 'age': 60, 'Gender': 'Male', 'subjects': ['maths', 'Science'], 'city': 'baltimore'}

# %%
person.pop('city')
# Out:
# 'baltimore'

# %%
person
# Out:
# {'name': 'aayam',
#  'age': 60,
#  'Gender': 'Male',
#  'subjects': ['maths', 'Science']}

# %%
del person['age']

# %%
person
# Out:
# {'name': 'aayam', 'Gender': 'Male', 'subjects': ['maths', 'Science']}

# %% [markdown]
# ### Dictionary Methods

# %%
print(person)
# Out:
# {'name': 'aayam', 'Gender': 'Male', 'subjects': ['maths', 'Science']}

# %%
person.keys()
# Out:
# dict_keys(['name', 'Gender', 'subjects'])

# %%
person.values()
# Out:
# dict_values(['aayam', 'Male', ['maths', 'Science']])

# %%
print(person.items())
# Out:
# dict_items([('name', 'aayam'), ('Gender', 'Male'), ('subjects', ['maths', 'Science'])])

# %%
person2 = person.copy()
person2["gender"] = "Female"
person2
# Out:
# {'name': 'aayam',
#  'Gender': 'Male',
#  'subjects': ['maths', 'Science'],
#  'gender': 'Female'}

# %%
person
# Out:
# {'name': 'aayam', 'Gender': 'Male', 'subjects': ['maths', 'Science']}

# %% [markdown]
# ### Merge Dicts

# %%
dict1 = {"name" : "sam", "age" :65}
dict2 = {"regno" : 456, "subjects" :["maths"]}

# %%
dict1 | dict2
# Out:
# {'name': 'sam', 'age': 65, 'regno': 456, 'subjects': ['maths']}

# %% [markdown]
# ### sorted() Method

# %%
person = {"name" : "John", "age":"30", "city":"new york","gender":"Male"}

# %%
person.items()
# Out:
# dict_items([('name', 'John'), ('age', '30'), ('city', 'new york'), ('gender', 'Male')])

# %%
dict(
    sorted(
        person.items(),
        key=lambda item: item[1]))
# Out:
# {'age': '30', 'name': 'John', 'gender': 'Male', 'city': 'new york'}
