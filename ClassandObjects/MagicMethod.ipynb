# %% [markdown]
# ## Magic Methods in Python

# %%
class Person:
    def __init__(objr, name, age):
        objr.name = name
        objr.age = age

    def __str__(objr):
        return f"{objr.name} of {objr.age} years old"

    def __repr__(objr):
        return f"Person {objr.name}, {objr.age}"

    def __len__(objr):
        return objr.age

    def __call__(objr, gender = "Male"):#< object to callable
        return f"{objr.name} is a {gender}"

# %%
person = Person("aayam", 20)

# %%
person.name
# Out:
# 'aayam'

# %%
print(person)
# Out:
# aayam of 20 years old

# %%
person
# Out:
# Person aayam, 20

# %%
len(person)
# Out:
# 20

# %%
person("Male")
# Out:
# 'aayam is a Male'
